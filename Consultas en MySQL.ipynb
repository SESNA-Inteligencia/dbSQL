# %% [markdown]
# # <center> **Consultas en MySQL**

# %%
import pandas as pd
import numpy as np
import requests
from sqlalchemy import create_engine
import sys
import pymysql
import mysql
import mysql.connector

# %%
# Configuración para conexión
user='root'
password='astro123'
host='localhost'
database='sesna'

# %%
# coneccion
db= mysql.connector.connect(user=user, 
                            password=password,
                            host=host,
                            database=database)
#cnx.close()

# %% [markdown]
# Vamos a consultar la tabla INEGI de la base "SESNA".

# %%
consulta = pd.read_sql('SELECT * from inegi;', con=db)
consulta.head()
# Out:
# c:\Users\jcmartinez\Anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    id  CVE_ENT         NOM_ENT NOM_ABR  CVE_MUN         NOM_MUN  CVE_LOC  \
# 0   1      1.0  Aguascalientes    Ags.      1.0  Aguascalientes      1.0
# 1   2      1.0  Aguascalientes    Ags.      1.0  Aguascalientes     94.0
# 2   3      1.0  Aguascalientes    Ags.      1.0  Aguascalientes     96.0
# 3   4      1.0  Aguascalientes    Ags.      1.0  Aguascalientes    100.0
# 4   5      1.0  Aguascalientes    Ags.      1.0  Aguascalientes    102.0
#
#                   NOM_LOC AMBITO         LATITUD         LONGITUD  \
# 0          Aguascalientes      U  21°52´47.362N"  102°17´45.768W"
# 1          Granja Adelita      R  21°52´18.749N"  102°22´24.710W"
# ...

# %% [markdown]
# Podemos contar las localidades por cada municipio

# %%
consulta02 = pd.read_sql('SELECT CVE_MUN, NOM_MUN from inegi;', con=db)
consulta02.head()
# Out:
#    CVE_MUN         NOM_MUN
# 0      1.0  Aguascalientes
# 1      1.0  Aguascalientes
# 2      1.0  Aguascalientes
# 3      1.0  Aguascalientes
# 4      1.0  Aguascalientes
